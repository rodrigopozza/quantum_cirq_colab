# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigopozza/quantum_cirq_colab/blob/main/Quantum_AI_POZZA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tratativa de erro no colab caso não esteja instalado framework no notebook
try:
    import cirq
except ImportError:
    print("installing cirq...")
    # !pip install --quiet cirq
    import cirq

    print("installed cirq.")

qubits = cirq.GridQubit.square(3)

print("\n",qubits[0],"\n")

print("\n",qubits,"\n")


# Este é um porta Pauli X. É uma instância de objeto.
x_gate = cirq.X
# Aplicando ao qubit no local (0, 0) (definido acima)
# transforma isso em uma operação.
x_op = x_gate(qubits[0])

print("\n operação: \n",x_op)

# criando momentos
cz = cirq.CZ(qubits[0], qubits[1])
x = cirq.X(qubits[2])
moment = cirq.Moment(x, cz)

print("\n momento:\n",moment)

cz01 = cirq.CZ(qubits[0], qubits[1])
x2 = cirq.X(qubits[2])
cz12 = cirq.CZ(qubits[1], qubits[2])
moment0 = cirq.Moment([cz01, x2])
moment1 = cirq.Moment([cz12])
circuit = cirq.Circuit((moment0, moment1))

print("\n circuito:\n",circuit)
# Out:
#  q(0, 0)
#
#
#  [cirq.GridQubit(0, 0), cirq.GridQubit(0, 1), cirq.GridQubit(0, 2), cirq.GridQubit(1, 0), cirq.GridQubit(1, 1), cirq.GridQubit(1, 2), cirq.GridQubit(2, 0), cirq.GridQubit(2, 1), cirq.GridQubit(2, 2)]
#
#
#  operação:
#  X(q(0, 0))
#
#  momento:
#    ╷ 0 1 2
# ╶─┼───────
# 0 │ @─@ X
#   │
#
#  circuito:
#  (0, 0): ───@───────
#            │
# (0, 1): ───@───@───
#                │
# (0, 2): ───X───@───
