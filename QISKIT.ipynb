# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigopozza/quantum_cirq_colab/blob/main/QISKIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # API

# %%
api_key = 'ApiKey-3ed234e1-7d67-4240-a9ee-a57c90fd49b6'

# %% [markdown]
# # import

# %%
# !pip install qiskit

# %% [markdown]
# # teste

# %%
import qiskit
qiskit.__version__
# Out:
# '2.2.1'

# %% [markdown]
# #login IBM

# %%
# Enable your account on Qiskit, replace 'My_API_Token' with your newly generated token
qiskit.IBMQ.save_account('f0f41171ded944908620b2c2b77ea8e2')
qiskit.IBMQ.load_accounts(f0f41171ded944908620b2c2b77ea8e2)
# After loading credentials we query the backends
qiskit.IBMQ.backends()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-732135752.py in <cell line: 0>()
#       1 # Enable your account on Qiskit, replace 'My_API_Token' with your newly generated token
# ----> 2 qiskit.IBMQ.save_account('f0f41171ded944908620b2c2b77ea8e2')
#       3 qiskit.IBMQ.load_accounts(f0f41171ded944908620b2c2b77ea8e2)
#       4 # After loading credentials we query the backends
#       5 qiskit.IBMQ.backends()
#
# AttributeError: module 'qiskit' has no attribute 'IBMQ'

# %% [markdown]
# # COMPOSER

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])

print(a,b)
# Out:
#   File "/tmp/ipython-input-74978303.py", line 10
#     a = circuit.measure(qreg_q[0], creg_c[0])
#     ^
# IndentationError: unexpected indent
